# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import load_data as ld
import pickle

# %%
#creating no-meta-learning datasets

task_size = 500
mode = "no-meta-learning"
M = "NOML"

dataset_name = "POLLUTION"
window_size = 5
##pollution
train_dataset, validation_dataset, test_dataset = ld.load_data_pollution(window_size = window_size, 
                                                                         task_size = task_size, 
                                                                         stride=1, mode=mode)

pickle_out = open("../Data/TRAIN-"+dataset_name+"-W"+str(window_size)+"-T"+str(task_size)+"-"+M+".pickle", "wb")
pickle.dump(train_dataset, pickle_out)
pickle_out.close()

pickle_out = open("../Data/VAL-"+dataset_name+"-W"+str(window_size)+"-T"+str(task_size)+"-"+M+".pickle", "wb")
pickle.dump(validation_dataset, pickle_out)
pickle_out.close()

pickle_out = open("../Data/TEST-"+dataset_name+"-W"+str(window_size)+"-T"+str(task_size)+"-"+M+".pickle", "wb")
pickle.dump(test_dataset, pickle_out)
pickle_out.close()
# Out:
# Filtering samples with invalid targets...
# where to delete: (0,)
# x shape: (52579, 5, 14)
# y shape: (52579, 1)
# Filtering samples with invalid targets...
# where to delete: (20748,)
# x shape: (31831, 5, 14)
# y shape: (31831, 1)
# Filtering samples with invalid targets...
# where to delete: (17506,)
# x shape: (35073, 5, 14)
# y shape: (35073, 1)
# Filtering samples with invalid targets...
# where to delete: (17188,)
# x shape: (35391, 5, 14)
# y shape: (35391, 1)
# Filtering samples with invalid targets...
# where to delete: (28947,)
# x shape: (23632, 5, 14)
# y shape: (23632, 1)

# %%
task_size = 500
#mode = "meta-learning"
#M = "ML"

dataset_name = "BATTERY"
window_size = 20
train_dataset, validation_dataset, test_dataset = ld.load_battery_data(window_size = window_size, 
                                                                         task_size = task_size, 
                                                                         stride=10, mode=mode)


pickle_out = open("../Data/TRAIN-"+dataset_name+"-W"+str(window_size)+"-T"+str(task_size)+"-"+M+".pickle", "wb")
pickle.dump(train_dataset, pickle_out)
pickle_out.close()

pickle_out = open("../Data/VAL-"+dataset_name+"-W"+str(window_size)+"-T"+str(task_size)+"-"+M+".pickle", "wb")
pickle.dump(validation_dataset, pickle_out)
pickle_out.close()

pickle_out = open("../Data/TEST-"+dataset_name+"-W"+str(window_size)+"-T"+str(task_size)+"-"+M+".pickle", "wb")
pickle.dump(test_dataset, pickle_out)
pickle_out.close()
# Out:
# x shape: (6891, 20, 3)
# y shape: (6891, 1)
# x shape: (28424, 20, 3)
# y shape: (28424, 1)
# x shape: (9705, 20, 3)
# y shape: (9705, 1)
# x shape: (6891, 20, 3)
# y shape: (6891, 1)
# x shape: (9705, 20, 3)
# y shape: (9705, 1)
# x shape: (9705, 20, 3)
# y shape: (9705, 1)
# x shape: (28424, 20, 3)
# y shape: (28424, 1)
# x shape: (9705, 20, 3)
# y shape: (9705, 1)
# x shape: (6464, 20, 3)
# y shape: (6464, 1)
# x shape: (9461, 20, 3)
# y shape: (9461, 1)
# x shape: (28389, 20, 3)
# y shape: (28389, 1)
# x shape: (9451, 20, 3)
# y shape: (9451, 1)
# x shape: (28424, 20, 3)
# y shape: (28424, 1)
# x shape: (28389, 20, 3)
# y shape: (28389, 1)
# x shape: (28389, 20, 3)
# y shape: (28389, 1)
# x shape: (6407, 20, 3)
# y shape: (6407, 1)
# x shape: (28389, 20, 3)
# y shape: (28389, 1)
# x shape: (6374, 20, 3)
# y shape: (6374, 1)
# x shape: (28389, 20, 3)
# y shape: (28389, 1)
# x shape: (9705, 20, 3)
# y shape: (9705, 1)
# x shape: (6252, 20, 3)
# y shape: (6252, 1)
# ...

# %%
dataset_name = "HR"
window_size = 32
train_dataset, validation_dataset, test_dataset = ld.load_data_heart_rate(window_size = window_size, 
                                                                         task_size = task_size, 
                                                                         stride=4, mode=mode)

pickle_out = open("../Data/TRAIN-"+dataset_name+"-W"+str(window_size)+"-T"+str(task_size)+"-"+M+".pickle", "wb")
pickle.dump(train_dataset, pickle_out)
pickle_out.close()

pickle_out = open("../Data/VAL-"+dataset_name+"-W"+str(window_size)+"-T"+str(task_size)+"-"+M+".pickle", "wb")
pickle.dump(validation_dataset, pickle_out)
pickle_out.close()

pickle_out = open("../Data/TEST-"+dataset_name+"-W"+str(window_size)+"-T"+str(task_size)+"-"+M+".pickle", "wb")
pickle.dump(test_dataset, pickle_out)
pickle_out.close()
# Out:
# Processing subject  S1 ...
# Processed data with shape: (36815, 22)
# x shape: (9196, 32, 13)
# y shape: (9196, 1)
# Processing subject  S2 ...
# Processed data with shape: (32788, 22)
# x shape: (8189, 32, 13)
# y shape: (8189, 1)
# Processing subject  S3 ...
# Processed data with shape: (34931, 22)
# x shape: (8725, 32, 13)
# y shape: (8725, 1)
# Processing subject  S4 ...
# Processed data with shape: (36567, 22)
# x shape: (9134, 32, 13)
# y shape: (9134, 1)
# Processing subject  S5 ...
# Processed data with shape: (37188, 22)
# x shape: (9289, 32, 13)
# y shape: (9289, 1)
# Processing subject  S6 ...
# Processed data with shape: (20967, 22)
# x shape: (5234, 32, 13)
# y shape: (5234, 1)
# Processing subject  S7 ...
# Processed data with shape: (37338, 22)
# x shape: (9327, 32, 13)
# y shape: (9327, 1)
# Processing subject  S8 ...
# Processed data with shape: (32286, 22)
# x shape: (8064, 32, 13)
# y shape: (8064, 1)
# Processing subject  S9 ...
# ...
